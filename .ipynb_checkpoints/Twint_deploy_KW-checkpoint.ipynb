# %%
# Initial Imports
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
from pathlib import Path
import regex as re
import nltk
from datetime import date
import twint
import nest_asyncio
nest_asyncio.apply()
nltk.download('stopwords')

# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kevinwalsh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Initialize set of inputs
# List of Stocks
stocks = ['microsoft','sony','pfizer','regeneron','moderna']

# Set up Date range
import datetime
from dateutil.relativedelta import relativedelta

today = datetime.date.today()
end_time = today.strftime('%Y-%m-%d %H:%M:%S')
start_time = today - relativedelta(years=1)
start_time = start_time.strftime('%Y-%m-%d %H:%M:%S')
print(start_time)
# Out:
# 2020-01-19 00:00:00

# %%
# Define Empty DataFrames
stock_df = pd.DataFrame()
df = pd.DataFrame()

# %%
# Define data_crawlers function
def data_crawlers(stock):
    c = twint.Config()
    c.Search = stock
    c.Hide_output = True
    c.Limit = 1000 
    #c.Store_csv = True
    c.Since = start_time
    c.Until = end_time
    #c.Output = f"{stock}.csv"
    c.Pandas = True
    c.Pandas_au = True
    twint.run.Search(c)
    df = twint.storage.panda.Tweets_df
    df.index=idx_microsoft=pd.MultiIndex.from_tuples([tuple([stock, i]) for i in range(len(df.index))])
    return df

# %%
# Test function
df_test=data_crawlers(stocks[0])
df_test.tail()
# Out:
#                                  id      conversation_id    created_at  \
# microsoft 1040  1350913315224969221  1350913315224969221  1.610918e+12
#           1041  1350913217594232833  1350913217594232833  1.610918e+12
#           1042  1350913173159866372  1350913173159866372  1.610918e+12
#           1043  1350913058055593994  1350913058055593994  1.610918e+12
#           1044  1350913046374461448  1350913046374461448  1.610918e+12
#
#                                date timezone place  \
# microsoft 1040  2021-01-17 16:10:07    -0500
#           1041  2021-01-17 16:09:44    -0500
#           1042  2021-01-17 16:09:33    -0500
#           1043  2021-01-17 16:09:06    -0500
#           1044  2021-01-17 16:09:03    -0500
#
#                                                             tweet language  \
# microsoft 1040  Microsoft Announces Experimental Source Code C...       en
#           1041  Microsoft Patch Tuesday, January 2021 Edition ...       en
#           1042  How to Make a Microsoft PowerPoint Presentatio...       en
#           1043  Credenciales Digitales de Vacunación contra el...       es
#           1044  Ran pipeline 30 times last Friday to try and g...       en
#
#                            hashtags cashtags  ...  geo source user_rt_id  \
# microsoft 1040  [powerapps, vscode]       []  ...
#           1041                   []       []  ...
#           1042                   []       []  ...
#           1043                   []       []  ...
#           1044                   []       []  ...
#
#                user_rt  retweet_id reply_to retweet_date translate trans_src  \
# microsoft 1040                           []
#           1041                           []
#           1042                           []
#           1043                           []
#           1044                           []
#
#                 trans_dest
# microsoft 1040
#           1041
#           1042
#           1043
#           1044
#
# [5 rows x 38 columns]

# %%
# Deploy data_crawlers function on stocks list
for i in stocks: 
    data_crawlers(i)
    df = twint.storage.panda.Tweets_df
    stock_df = stock_df.append(df)

# %%
# Read tweets as strings
stock_df['tweet'] = stock_df['tweet'].astype(str)

# %%
# Filter on tweets only in english
stock_df = stock_df[stock_df['language'] == 'en']

# Pull in only the raw Twitter text
stock_df = pd.DataFrame(stock_df['tweet'])

# %%
# Visualize New DataFrame
stock_df.tail()
# Out:
#                                                          tweet
# moderna 991  @UkTuff Do you understand what owning a share ...
#         992  @minisciencegirl @momof3turkeys @VirusesImmuni...
#         994  @AlexBerenson @moderna_tx Alex what are your t...
#         996  @StopCoronavir12 I think the moving of the sec...
#         997  @CityNews Moderna isn’t effective against the ...

# %% [markdown]
# # Sentiment Analysis

# %%
# Create a Master copy of the stock_df
master_df = stock_df.copy()
master_df = master_df.reset_index(drop=True)

# Perform Sentiment Analysis
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.stem import WordNetLemmatizer 
analyzer = SentimentIntensityAnalyzer()
tweet_sent = {'Compound':[],
                 'Negative':[],
                 'Neutral':[],
                 'Positive':[]}
# Get sentiment from articles
for index, row in master_df.iterrows():
    try:
        tweet_sentiment = analyzer.polarity_scores(row["tweet"])
        tweet_sent["Compound"].append(tweet_sentiment["compound"])
        tweet_sent["Negative"].append(tweet_sentiment["neg"])
        tweet_sent["Neutral"].append(tweet_sentiment["neu"])
        tweet_sent["Positive"].append(tweet_sentiment["pos"])
    except AttributeError:
        pass
# Add the newly created scores to the previously created bitcoin dataframe
tweet_sent_df = pd.DataFrame(tweet_sent)
master_df = tweet_sent_df.join(master_df)
master_df.head()
# Out:
#    Compound  Negative  Neutral  Positive  \
# 0    0.8074      0.00    0.711     0.289
# 1    0.1245      0.07    0.852     0.078
# 2   -0.1957      0.12    0.880     0.000
# 3    0.0000      0.00    1.000     0.000
# 4    0.7269      0.00    0.534     0.466
#
#                                                tweet
# 0  Rhipe, NTT Data, Adobe win Microsoft APAC part...
# 1  To Microsoft. See apple had no care about vide...
# 2  @SnoopyG7 Microsoft said its coming to gamepas...
# 3  How is it 2021, the year of constant zoom call...
# 4  The chromium-based version of Microsoft Edge i...

# %%
# Split the Dataframe into separate DataFrames based on topic
for stock in stocks:
    vars()[stock] = pd.DataFrame(stock_df.loc[stock,:])
    tweet_sent = {'Compound':[],
                 'Negative':[],
                 'Neutral':[],
                 'Positive':[]}
    for index, row in vars()[stock].iterrows():
        try:
            tweet_sentiment = analyzer.polarity_scores(row["tweet"])
            tweet_sent["Compound"].append(tweet_sentiment["compound"])
            tweet_sent["Negative"].append(tweet_sentiment["neg"])
            tweet_sent["Neutral"].append(tweet_sentiment["neu"])
            tweet_sent["Positive"].append(tweet_sentiment["pos"])
        except AttributeError:
            pass
    tweet_sent_df = pd.DataFrame(tweet_sent)
    vars()[stock] = tweet_sent_df.join(vars()[stock])
    vars()[stock] = vars()[stock].dropna()
    vars()[stock] = vars()[stock].reset_index(drop=True)
for stock in stocks:
    display(vars()[stock])
# Out:
#      Compound  Negative  Neutral  Positive  \
# 0      0.1245     0.070    0.852     0.078
# 1     -0.1957     0.120    0.880     0.000
# 2      0.7269     0.000    0.534     0.466
# 3      0.0000     0.000    1.000     0.000
# 4     -0.6312     0.133    0.867     0.000
# ..        ...       ...      ...       ...
# 478    0.6908     0.000    0.695     0.305
# 479    0.0000     0.000    1.000     0.000
# 480    0.0000     0.000    1.000     0.000
# 481    0.0000     0.000    1.000     0.000
# 482    0.0000     0.000    1.000     0.000
#
#                                                  tweet
# 0    Rhipe, NTT Data, Adobe win Microsoft APAC part...
# 1    To Microsoft. See apple had no care about vide...
# 2    @SnoopyG7 Microsoft said its coming to gamepas...
# 3    How is it 2021, the year of constant zoom call...
# 4    The chromium-based version of Microsoft Edge i...
# ..                                                 ...
# 478  @ChitoGaminYT Knowing microsoft this will take...
# 479  Paper Matt From Wii Sports Gets Found in the F...
# 480  Testing Microsoft Teams new feature breakout r...
# 481  Microsoft-owned GitHub apologizes for controve...
# 482  @J4Yx2 ASUS Laptop L406 Thin and Light Laptop,...
#
# [483 rows x 5 columns]
#      Compound  Negative  Neutral  Positive  \
# 0      0.0000     0.000    1.000     0.000
# 1      0.2640     0.096    0.772     0.131
# 2     -0.6597     0.157    0.843     0.000
# 3      0.6093     0.096    0.736     0.169
# 4      0.4927     0.000    0.715     0.285
# ..        ...       ...      ...       ...
# 418    0.9300     0.000    0.622     0.378
# 419   -0.3094     0.039    0.940     0.020
# 420    0.6124     0.000    0.839     0.161
# 421   -0.3182     0.132    0.742     0.126
# 422    0.6124     0.000    0.815     0.185
#
#                                                  tweet
# 0    @PatchesTheTrusy @xxogballer69xx @NEPlaybookYT...
# 1       @PlayStation When will you restock Canada !???
# 2    @BenVolin Honestly do these people watch footb...
# 3    @MartitaO @defilinski @catheri54658661 @aaronc...
# 4    @ponywrangler19 @rickpassarin @PatientGamer2 @...
# ..                                                 ...
# 418  @Oshamoff @LogicalMcrochip IDK why, but Sony's...
# 419  Fucking Crazy that i broke up with my girlfrie...
# 420  @f_allsop @Evellxe @NextGenPlayer This console...
# 421  I just want to say give Sony a break, Everyone...
# 422  @CharmlessNurk Sorry, wrong people   Get SONY ...
#
# [423 rows x 5 columns]
#      Compound  Negative  Neutral  Positive  \
# 0     -0.8316     0.302    0.698     0.000
# 1      0.2755     0.000    0.928     0.072
# 2      0.4215     0.000    0.909     0.091
# 3     -0.8796     0.188    0.812     0.000
# 4      0.1868     0.056    0.868     0.076
# ..        ...       ...      ...       ...
# 104   -0.0572     0.092    0.908     0.000
# 105    0.6486     0.000    0.908     0.092
# 106   -0.7650     0.398    0.602     0.000
# 107   -0.1680     0.135    0.749     0.116
# 108    0.0000     0.000    1.000     0.000
#
#                                                  tweet
# 0    Pfizer COVID Vaccine Trial Showed Alarming Evi...
# 1    13 Israelis Suffer Facial Paralysis After Pfiz...
# 2    Reminder about Pfizer BioNtech #COVID19 vaccin...
# 3    @llamakip The single dose of the Pfizer Vax is...
# 4    @candylush Both my parents have had both shots...
# ..                                                 ...
# 104  Mommy and daddy, sitting in a tree This is fro...
# 105  @Pmjk1 Are people having to travel far for the...
# 106  @rebel_routine mRNA has been around for years,...
# 107  92% is looking more like a number Pfizer made ...
# 108  Provinces work on revised plans as Pfizer-BioN...
#
# [109 rows x 5 columns]
#      Compound  Negative  Neutral  Positive  \
# 0     -0.5423     0.412    0.588     0.000
# 1      0.0000     0.000    1.000     0.000
# 2      0.1406     0.000    0.956     0.044
# 3      0.0000     0.000    1.000     0.000
# 4      0.3612     0.000    0.800     0.200
# ..        ...       ...      ...       ...
# 402    0.0000     0.000    1.000     0.000
# 403   -0.2398     0.179    0.821     0.000
# 404    0.0000     0.000    1.000     0.000
# 405   -0.2023     0.153    0.847     0.000
# 406    0.0000     0.000    1.000     0.000
#
#                                                  tweet
# 0         @MAGAMedium1_7 Mike unmasked, Bad role over?
# 1                        @SecPompeo Morse on the wall?
# 2    @Regeneron Research alternative approaches tha...
# 3    @northernsky67 @tazwake If he wants to move to...
# 4    @FantasticVulpes Don't know how far along or h...
# ..                                                 ...
# 402  Thrilled to share our #ZipChip solution has be...
# 403  @springsdeb @donwinslow @laurenboebert @FBI Th...
# 404  JPM, Day 3: CureVac partner Bayer says not to ...
# 405  JPM, Day 3: CureVac partner Bayer says not to ...
# 406  E-boy and his podcaster boyfriend  https://t.c...
#
# [407 rows x 5 columns]
#      Compound  Negative  Neutral  Positive  \
# 0      0.4397     0.000    0.782     0.218
# 1      0.0000     0.000    1.000     0.000
# 2      0.0000     0.000    1.000     0.000
# 3     -0.3987     0.136    0.864     0.000
# 4      0.6486     0.061    0.771     0.168
# ..        ...       ...      ...       ...
# 175    0.0000     0.000    1.000     0.000
# 176    0.0000     0.000    1.000     0.000
# 177    0.6801     0.000    0.861     0.139
# 178    0.0000     0.000    1.000     0.000
# 179    0.2263     0.095    0.812     0.092
#
#                                                  tweet
# 0    @pancakeliberty The Moderna vaccine is not in ...
# 1    Coffee County in Kansas Staffers have opted ou...
# 2    Long #Moderna, they are the other answer. NOT ...
# 3    .@sbancel You have a responsibility to make su...
# 4    Moderna CEO says the world will have to live w...
# ..                                                 ...
# 175  #Covid19 vaccine: Latest updates on #Oxford, #...
# 176  “Despite being a G7 nation, and one of the fir...
# 177  @MattHaneySF Let’s remember to be clear everyo...
# 178  @thickopedia Is it late to buy some shares in ...
# 179  @amnesty @AstraZeneca @JNJNews @moderna_tx @No...
#
# [180 rows x 5 columns]
