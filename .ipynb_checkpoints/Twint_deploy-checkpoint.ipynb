# %%
# Initial Imports
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
from pathlib import Path
import regex as re
import nltk
from datetime import date
import twint
import nest_asyncio
nest_asyncio.apply()
nltk.download('stopwords')

# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kevinwalsh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Initialize set of inputs
# List of Stocks
stocks = ['microsoft','sony','pfizer','regeneron','moderna']

# Set up Date range
import datetime
from dateutil.relativedelta import relativedelta

today = datetime.date.today()
end_time = today.strftime('%Y-%m-%d %H:%M:%S')
start_time = today - relativedelta(years=1)
start_time = start_time.strftime('%Y-%m-%d %H:%M:%S')
print(start_time)
# Out:
# 2020-01-19 00:00:00

# %%
# Define data_crawlers function
stock_df = pd.DataFrame()
df = pd.DataFrame()

# %%
def data_crawlers(stock):
    c = twint.Config()
    c.Search = stock
    c.Hide_output = True
    c.Limit = 1000 
    #c.Store_csv = True
    c.Since = start_time
    c.Until = end_time
    #c.Output = f"{stock}.csv"
    c.Pandas = True
    c.Pandas_au = True
    twint.run.Search(c)
    #df = twint.storage.panda.Tweets_df

# %%
# Deploy data_crawlers function on stocks list
for i in stocks: 
    data_crawlers(i)
    df = twint.storage.panda.Tweets_df
    stock_df = stock_df.append(df)

# %%
stock_df = stock_df.reset_index(drop=True)
stock_df.tail()
# Out:
#                        id      conversation_id    created_at  \
# 5043  1350909911685877761  1350903498884440066  1.610917e+12
# 5044  1350909837320794118  1350815302318174209  1.610917e+12
# 5045  1350909835982872577  1350780008026017795  1.610917e+12
# 5046  1350909792580214786  1349522780895776769  1.610917e+12
# 5047  1350909785949007876  1350909785949007876  1.610917e+12
#
#                      date timezone place  \
# 5043  2021-01-17 15:56:36    -0500
# 5044  2021-01-17 15:56:18    -0500
# 5045  2021-01-17 15:56:18    -0500
# 5046  2021-01-17 15:56:07    -0500
# 5047  2021-01-17 15:56:06    -0500
#
#                                                   tweet language hashtags  \
# 5043  @StopCoronavir12 I think the moving of the sec...       en       []
# 5044  @CityNews Moderna isn’t effective against the ...       en       []
# 5045  @Manhattanplanet @LuisLuluso @AlexandraJAlva4 ...       es       []
# 5046  @Uber @moderna_tx حصل مشكله علي الايمل بتاعي ش...       ar       []
# 5047  Mira yo soy moderna ....pero te voy a dar un c...       es       []
#
#      cashtags  ...  geo source user_rt_id user_rt  retweet_id  \
# 5043       []  ...
# 5044       []  ...
# 5045       []  ...
# 5046       []  ...
# 5047       []  ...
#
#                                                reply_to retweet_date  \
# 5043  [{'screen_name': 'StopCoronavir12', 'name': 'S...
# 5044  [{'screen_name': 'CityNews', 'name': 'CityNews...
# 5045  [{'screen_name': 'Manhattanplanet', 'name': 'D...
# 5046  [{'screen_name': 'Uber', 'name': 'Uber', 'id':...
# 5047                                                 []
#
#      translate trans_src  trans_dest
# 5043
# 5044
# 5045
# 5046
# 5047
#
# [5 rows x 38 columns]

# %%
df.head()
# Out:
#                     id      conversation_id    created_at  \
# 0  1350955153004916738  1350952921727455232  1.610928e+12
# 1  1350953689033400324  1350953689033400324  1.610927e+12
# 2  1350952249636364289  1350937872019435529  1.610927e+12
# 3  1350949622404030464  1350947657724944384  1.610926e+12
# 4  1350945783005196289  1348670741017989128  1.610926e+12
#
#                   date timezone place  \
# 0  2021-01-17 18:56:22    -0500
# 1  2021-01-17 18:50:33    -0500
# 2  2021-01-17 18:44:50    -0500
# 3  2021-01-17 18:34:24    -0500
# 4  2021-01-17 18:19:08    -0500
#
#                                                tweet language hashtags  \
# 0       @MAGAMedium1_7 Mike unmasked, Bad role over?       en       []
# 1  巨細胞性動脈炎へのSanofi/Regeneronの抗IL-6薬ケブザラのPh3試験中止  ...       ja       []
# 2                              @Poulin2012 Regeneron       es       []
# 3                      @SecPompeo Morse on the wall?       en       []
# 4  @Regeneron Research alternative approaches tha...       en       []
#
#   cashtags  ...  geo source user_rt_id user_rt  retweet_id  \
# 0       []  ...
# 1       []  ...
# 2       []  ...
# 3       []  ...
# 4       []  ...
#
#                                             reply_to retweet_date translate  \
# 0  [{'screen_name': 'MAGAMedium1_7', 'name': 'MAG...
# 1                                                 []
# 2  [{'screen_name': 'Poulin2012', 'name': 'Alexis...
# 3  [{'screen_name': 'SecPompeo', 'name': 'Secreta...
# 4  [{'screen_name': 'Regeneron', 'name': 'Regener...
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]

# %%
# Define function to read in csv
from pathlib import Path
def csv_import(stock):
    stock_path = Path(f'{stock}.csv')
    return stock_path

# %%
path_list = []
for i in stocks:
    i_df = pd.DataFrame()
    path_list.append(csv_import(i))
    for x in path_list: 
        x_df = pd.DataFrame()
        i_df = pd.read_csv(x)

# %%
i_df
# Out:
#                       id      conversation_id               created_at  \
# 0    1350955153004916738  1350952921727455232  2021-01-17 18:56:22 EST
# 1    1350953689033400324  1350953689033400324  2021-01-17 18:50:33 EST
# 2    1350952249636364289  1350937872019435529  2021-01-17 18:44:50 EST
# 3    1350949622404030464  1350947657724944384  2021-01-17 18:34:24 EST
# 4    1350945783005196289  1348670741017989128  2021-01-17 18:19:08 EST
# ..                   ...                  ...                      ...
# 995  1349270518021689344  1349249571852083202  2021-01-13 03:22:14 EST
# 996  1349269443784937475  1349136478534852615  2021-01-13 03:17:58 EST
# 997  1349268537186136064  1349268537186136064  2021-01-13 03:14:22 EST
# 998  1349267891821142017  1349267891821142017  2021-01-13 03:11:48 EST
# 999  1349262573473046528  1349238288385765376  2021-01-13 02:50:40 EST
#
#            date      time  timezone              user_id         username  \
# 0    2021-01-17  18:56:22      -500  1316463156638687232        nregenero
# 1    2021-01-17  18:50:33      -500             46297868       seigomaeda
# 2    2021-01-17  18:44:50      -500            472672661        vicvegaaa
# 3    2021-01-17  18:34:24      -500  1316463156638687232        nregenero
# 4    2021-01-17  18:19:08      -500           1564480639        geminifty
# ..          ...       ...       ...                  ...              ...
# 995  2021-01-13  03:22:14      -500             17752824     manuel_storm
# 996  2021-01-13  03:17:58      -500  1222787807212642304    shimi30809579
# 997  2021-01-13  03:14:22      -500   833648789646868482  markgil30446463
# 998  2021-01-13  03:11:48      -500  1216415104436252672        stubenali
# 999  2021-01-13  02:50:40      -500           2473266547          aellynd
#
#                                        name  place  ... geo source user_rt_id  \
# 0                                 RegeneroN    NaN  ... NaN    NaN        NaN
# 1    前田静吾｜海外情報活用コンサルタント　Insights4 Pharma編集長    NaN  ... NaN    NaN        NaN
# 2                                       Vic    NaN  ... NaN    NaN        NaN
# 3                                 RegeneroN    NaN  ... NaN    NaN        NaN
# 4                                  Ginny LR    NaN  ... NaN    NaN        NaN
# ..                                      ...    ...  ...  ..    ...        ...
# 995                                  Manuel    NaN  ... NaN    NaN        NaN
# 996                                   shimi    NaN  ... NaN    NaN        NaN
# 997                            Mark Gilbert    NaN  ... NaN    NaN        NaN
# 998                                    paul    NaN  ... NaN    NaN        NaN
# 999                                   Timon    NaN  ... NaN    NaN        NaN
#
#     user_rt retweet_id                                           reply_to  \
# 0       NaN        NaN  [{'screen_name': 'MAGAMedium1_7', 'name': 'MAG...
# 1       NaN        NaN                                                 []
# 2       NaN        NaN  [{'screen_name': 'Poulin2012', 'name': 'Alexis...
# 3       NaN        NaN  [{'screen_name': 'SecPompeo', 'name': 'Secreta...
# 4       NaN        NaN  [{'screen_name': 'Regeneron', 'name': 'Regener...
# ..      ...        ...                                                ...
# 995     NaN        NaN  [{'screen_name': 'mittdolcino', 'name': 'mittd...
# 996     NaN        NaN  [{'screen_name': 'drainvillepm', 'name': 'Bern...
# 997     NaN        NaN                                                 []
# 998     NaN        NaN                                                 []
# 999     NaN        NaN  [{'screen_name': 'les_vaxxeuses', 'name': '💉Le...
#
#      retweet_date  translate trans_src trans_dest
# 0             NaN        NaN       NaN        NaN
# 1             NaN        NaN       NaN        NaN
# 2             NaN        NaN       NaN        NaN
# 3             NaN        NaN       NaN        NaN
# 4             NaN        NaN       NaN        NaN
# ..            ...        ...       ...        ...
# 995           NaN        NaN       NaN        NaN
# 996           NaN        NaN       NaN        NaN
# 997           NaN        NaN       NaN        NaN
# 998           NaN        NaN       NaN        NaN
# 999           NaN        NaN       NaN        NaN
#
# [1000 rows x 36 columns]

# %%
x_df.tail()
# Out:
#                       id      conversation_id               created_at  \
# 995  1349270518021689344  1349249571852083202  2021-01-13 03:22:14 EST
# 996  1349269443784937475  1349136478534852615  2021-01-13 03:17:58 EST
# 997  1349268537186136064  1349268537186136064  2021-01-13 03:14:22 EST
# 998  1349267891821142017  1349267891821142017  2021-01-13 03:11:48 EST
# 999  1349262573473046528  1349238288385765376  2021-01-13 02:50:40 EST
#
#            date      time  timezone              user_id         username  \
# 995  2021-01-13  03:22:14      -500             17752824     manuel_storm
# 996  2021-01-13  03:17:58      -500  1222787807212642304    shimi30809579
# 997  2021-01-13  03:14:22      -500   833648789646868482  markgil30446463
# 998  2021-01-13  03:11:48      -500  1216415104436252672        stubenali
# 999  2021-01-13  02:50:40      -500           2473266547          aellynd
#
#              name  place  ... geo source user_rt_id user_rt retweet_id  \
# 995        Manuel    NaN  ... NaN    NaN        NaN     NaN        NaN
# 996         shimi    NaN  ... NaN    NaN        NaN     NaN        NaN
# 997  Mark Gilbert    NaN  ... NaN    NaN        NaN     NaN        NaN
# 998          paul    NaN  ... NaN    NaN        NaN     NaN        NaN
# 999         Timon    NaN  ... NaN    NaN        NaN     NaN        NaN
#
#                                               reply_to  retweet_date  \
# 995  [{'screen_name': 'mittdolcino', 'name': 'mittd...           NaN
# 996  [{'screen_name': 'drainvillepm', 'name': 'Bern...           NaN
# 997                                                 []           NaN
# 998                                                 []           NaN
# 999  [{'screen_name': 'les_vaxxeuses', 'name': '💉Le...           NaN
#
#      translate trans_src trans_dest
# 995        NaN       NaN        NaN
# 996        NaN       NaN        NaN
# 997        NaN       NaN        NaN
# 998        NaN       NaN        NaN
# 999        NaN       NaN        NaN
#
# [5 rows x 36 columns]

# %%
csv_import('microsoft')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-80-a032750ab90b> in <module>
# ----> 1 csv_import('microsoft')
#
# <ipython-input-79-f937ef4f9859> in csv_import(stock)
#       1 def csv_import(stock):
# ----> 2     print(stock_csv)
#
# NameError: name 'stock_csv' is not defined
