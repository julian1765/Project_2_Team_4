# %%
# Initial Imports
from sklearn.preprocessing import LabelEncoder
import pandas as pd
import numpy as np
from pathlib import Path
import regex as re
import nltk
from datetime import date
import twint
import nest_asyncio
nest_asyncio.apply()
nltk.download('stopwords')

# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kevinwalsh/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Initialize set of inputs
# List of Stocks
stocks = ['microsoft','sony','pfizer','regeneron','moderna']

# Set up Date range
import datetime
from dateutil.relativedelta import relativedelta

today = datetime.date.today()
end_time = today.strftime('%Y-%m-%d %H:%M:%S')
start_time = today - relativedelta(years=1)
start_time = start_time.strftime('%Y-%m-%d %H:%M:%S')
print(start_time)
# Out:
# 2020-01-19 00:00:00

# %%
# Define data_crawlers function
stock_df = pd.DataFrame()
df = pd.DataFrame()

# %%
def data_crawlers(stock):
    c = twint.Config()
    c.Search = stock
    c.Hide_output = True
    c.Limit = 1000 
    #c.Store_csv = True
    c.Since = start_time
    c.Until = end_time
    #c.Output = f"{stock}.csv"
    c.Pandas = True
    c.Pandas_au = True
    twint.run.Search(c)
    df = twint.storage.panda.Tweets_df
    df.index=idx_microsoft=pd.MultiIndex.from_tuples([tuple([stock, i]) for i in range(len(df.index))])
    return df

# %%
df_microsoft=data_crawlers('microsoft')
df_microsoft.tail()
# Out:
#                                  id      conversation_id    created_at  \
# microsoft 1042  1350913335999430656  1350913335999430656  1.610918e+12
#           1043  1350913315224969221  1350913315224969221  1.610918e+12
#           1044  1350913217594232833  1350913217594232833  1.610918e+12
#           1045  1350913173159866372  1350913173159866372  1.610918e+12
#           1046  1350913058055593994  1350913058055593994  1.610918e+12
#
#                                date timezone place  \
# microsoft 1042  2021-01-17 16:10:12    -0500
#           1043  2021-01-17 16:10:07    -0500
#           1044  2021-01-17 16:09:44    -0500
#           1045  2021-01-17 16:09:33    -0500
#           1046  2021-01-17 16:09:06    -0500
#
#                                                             tweet language  \
# microsoft 1042  #Apple #Microsoft #Amazon #Google #Tesla  http...      und
#           1043  Microsoft Announces Experimental Source Code C...       en
#           1044  Microsoft Patch Tuesday, January 2021 Edition ...       en
#           1045  How to Make a Microsoft PowerPoint Presentatio...       en
#           1046  Credenciales Digitales de Vacunación contra el...       es
#
#                                                  hashtags cashtags  ...  geo  \
# microsoft 1042  [apple, microsoft, amazon, google, tesla]       []  ...
#           1043                        [powerapps, vscode]       []  ...
#           1044                                         []       []  ...
#           1045                                         []       []  ...
#           1046                                         []       []  ...
#
#                source user_rt_id user_rt  retweet_id reply_to retweet_date  \
# microsoft 1042                                             []
#           1043                                             []
#           1044                                             []
#           1045                                             []
#           1046                                             []
#
#                translate trans_src  trans_dest
# microsoft 1042
#           1043
#           1044
#           1045
#           1046
#
# [5 rows x 38 columns]

# %%
# Deploy data_crawlers function on stocks list
for i in stocks: 
    data_crawlers(i)
    df = twint.storage.panda.Tweets_df
    stock_df = stock_df.append(df)

# %%
stock_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
stock_df = stock_df.reset_index(drop=True)
stock_df.tail()
# Out:
#                        id      conversation_id    created_at  \
# 5043  1350909911685877761  1350903498884440066  1.610917e+12
# 5044  1350909837320794118  1350815302318174209  1.610917e+12
# 5045  1350909835982872577  1350780008026017795  1.610917e+12
# 5046  1350909792580214786  1349522780895776769  1.610917e+12
# 5047  1350909785949007876  1350909785949007876  1.610917e+12
#
#                      date timezone place  \
# 5043  2021-01-17 15:56:36    -0500
# 5044  2021-01-17 15:56:18    -0500
# 5045  2021-01-17 15:56:18    -0500
# 5046  2021-01-17 15:56:07    -0500
# 5047  2021-01-17 15:56:06    -0500
#
#                                                   tweet language hashtags  \
# 5043  @StopCoronavir12 I think the moving of the sec...       en       []
# 5044  @CityNews Moderna isn’t effective against the ...       en       []
# 5045  @Manhattanplanet @LuisLuluso @AlexandraJAlva4 ...       es       []
# 5046  @Uber @moderna_tx حصل مشكله علي الايمل بتاعي ش...       ar       []
# 5047  Mira yo soy moderna ....pero te voy a dar un c...       es       []
#
#      cashtags  ...  geo source user_rt_id user_rt  retweet_id  \
# 5043       []  ...
# 5044       []  ...
# 5045       []  ...
# 5046       []  ...
# 5047       []  ...
#
#                                                reply_to retweet_date  \
# 5043  [{'screen_name': 'StopCoronavir12', 'name': 'S...
# 5044  [{'screen_name': 'CityNews', 'name': 'CityNews...
# 5045  [{'screen_name': 'Manhattanplanet', 'name': 'D...
# 5046  [{'screen_name': 'Uber', 'name': 'Uber', 'id':...
# 5047                                                 []
#
#      translate trans_src  trans_dest
# 5043
# 5044
# 5045
# 5046
# 5047
#
# [5 rows x 38 columns]

# %%
df.head()
# Out:
#                     id      conversation_id    created_at  \
# 0  1350956035465506819  1350944512378630144  1.610928e+12
# 1  1350956016817623043  1350938315151839241  1.610928e+12
# 2  1350955967047987203  1350955558988369920  1.610928e+12
# 3  1350955932730208258  1350911267851141125  1.610928e+12
# 4  1350955861724827648  1350955861724827648  1.610928e+12
#
#                   date timezone place  \
# 0  2021-01-17 18:59:53    -0500
# 1  2021-01-17 18:59:48    -0500
# 2  2021-01-17 18:59:36    -0500
# 3  2021-01-17 18:59:28    -0500
# 4  2021-01-17 18:59:11    -0500
#
#                                                tweet language hashtags  \
# 0  @EMG_disciple 日本は遅いですよね😭 2月下旬と言われているものはPfizer/...       ja       []
# 1                       @pandelonico Familia moderna       ro       []
# 2  @pancakeliberty The Moderna vaccine is not in ...       en       []
# 3  @sebasugarte malas noticias son muchas persona...       es       []
# 4  Coffee County in Kansas Staffers have opted ou...       en       []
#
#   cashtags  ...  geo source user_rt_id user_rt  retweet_id  \
# 0       []  ...
# 1       []  ...
# 2       []  ...
# 3       []  ...
# 4       []  ...
#
#                                             reply_to retweet_date translate  \
# 0  [{'screen_name': 'EMG_disciple', 'name': 'ニューロ...
# 1  [{'screen_name': 'pandelonico', 'name': 'Nico ...
# 2  [{'screen_name': 'pancakeliberty', 'name': 'Sh...
# 3  [{'screen_name': 'sebasugarte', 'name': 'SEBAS...
# 4                                                 []
#
#   trans_src  trans_dest
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 38 columns]

# %%
# Define function to read in csv
from pathlib import Path
def csv_import(stock):
    stock_path = Path(f'{stock}.csv')
    return stock_path

# %%
path_list = []
for i in stocks:
    i_df = pd.DataFrame()
    path_list.append(csv_import(i))
    for x in path_list: 
        x_df = pd.DataFrame()
        i_df = pd.read_csv(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-ec8145c744d0> in <module>
#       5     for x in path_list:
#       6         x_df = pd.DataFrame()
# ----> 7         i_df = pd.read_csv(x)
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\anaconda3\envs\test\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File microsoft.csv does not exist: 'microsoft.csv'

# %%
i_df

# %%
x_df.tail()

# %%
csv_import('microsoft')
