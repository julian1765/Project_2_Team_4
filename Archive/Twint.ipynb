# %%
import twint
import nest_asyncio
nest_asyncio.apply()

def grab_tweets():
    c = twint.Config()
    #c.Username = "    "
    c.Search = 'tesla' 
    c.Since = '2021-01-01'
    c.Until = '2021-01-02'
#     c.Hide_output = True
#     c.Store_json = True
    c.Limit = 100
    c.Store_csv = True
#     c.Popular_tweets = True
    c.Output = "result1.csv"
    #c.Output = file
    return twint.run.Search(c)
#     Tweets_df = twint.storage.panda.Tweets_df
#     return Tweets_df

# %%
#grab_tweets('Tesla', 'tweets.json')
grab_tweets()

# %%
import twint
import nest_asyncio
nest_asyncio.apply()

import twint

c = twint.Config()

c.Search = 'tesla'
c.Hide_output = True
c.Limit = 50000  # Not working.
c.Store_csv = True
c.Since = '2020-01-01'
#c.Until = '2021-01-03'
c.Output = "result1.csv"

twint.run.Search(c)

# %%
import twint

# Configure
c = twint.Config()
c.Username = "realDonaldTrump"
c.Search = "great"

# Run
twint.run.Search(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-5c06d3b93bdd> in <module>
#       7
#       8 # Run
# ----> 9 twint.run.Search(c)
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\run.py in Search(config, callback)
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\run.py in run(config, callback)
#
# ~\anaconda3\envs\x\lib\site-packages\nest_asyncio.py in run_until_complete(self, future)
#      96                 raise RuntimeError(
#      97                     'Event loop stopped before Future completed.')
# ---> 98             return f.result()
#      99         finally:
#     100             self._thread_id = old_thread_id
#
# ~\anaconda3\envs\x\lib\asyncio\futures.py in result(self)
#     179         self.__log_traceback = False
#     180         if self._exception is not None:
# --> 181             raise self._exception
#     182         return self._result
#     183
#
# ~\anaconda3\envs\x\lib\asyncio\tasks.py in __step(***failed resolving arguments***)
#     249                 result = coro.send(None)
#     250             else:
# --> 251                 result = coro.throw(exc)
#     252         except StopIteration as exc:
#     253             if self._must_cancel:
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\run.py in main(self, callback)
#
# ~\anaconda3\envs\x\lib\asyncio\futures.py in __await__(self)
#     261         if not self.done():
#     262             self._asyncio_future_blocking = True
# --> 263             yield self  # This tells Task to wait for completion.
#     264         if not self.done():
#     265             raise RuntimeError("await wasn't used with future")
#
# ~\anaconda3\envs\x\lib\asyncio\tasks.py in __wakeup(self, future)
#     316     def __wakeup(self, future):
#     317         try:
# --> 318             future.result()
#     319         except Exception as exc:
#     320             # This may also be a cancellation.
#
# ~\anaconda3\envs\x\lib\asyncio\futures.py in result(self)
#     179         self.__log_traceback = False
#     180         if self._exception is not None:
# --> 181             raise self._exception
#     182         return self._result
#     183
#
# ~\anaconda3\envs\x\lib\asyncio\tasks.py in __step(***failed resolving arguments***)
#     247                 # We use the `send` method directly, because coroutines
#     248                 # don't have `__iter__` and `__next__` methods.
# --> 249                 result = coro.send(None)
#     250             else:
#     251                 result = coro.throw(exc)
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\run.py in run(self)
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\run.py in tweets(self)
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\run.py in Feed(self)
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\get.py in RequestUrl(config, init)
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\get.py in Request(_url, connector, params, headers)
#
# ~\AppData\Roaming\Python\Python37\site-packages\twint\get.py in Response(session, _url, params)
#
# ~\anaconda3\envs\x\lib\site-packages\aiohttp\client.py in __aenter__(self)
#    1115
#    1116     async def __aenter__(self) -> _RetType:
# -> 1117         self._resp = await self._coro
#    1118         return self._resp
#    1119
#
# ~\anaconda3\envs\x\lib\site-packages\aiohttp\client.py in _request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, proxy_headers, trace_request_ctx, read_bufsize)
#     511                         ssl=ssl,
#     512                         proxy_headers=proxy_headers,
# --> 513                         traces=traces,
#     514                     )
#     515
#
# ~\anaconda3\envs\x\lib\site-packages\aiohttp\client_reqrep.py in __init__(self, method, url, params, headers, skip_auto_headers, data, cookies, auth, version, compress, chunked, expect100, loop, response_class, proxy, proxy_auth, timer, session, ssl, proxy_headers, traces)
#     281         if params:
#     282             q = MultiDict(url.query)
# --> 283             url2 = url.with_query(params)
#     284             q.extend(url2.query)
#     285             url = url.with_query(q)
#
# ~\anaconda3\envs\x\lib\site-packages\yarl\__init__.py in with_query(self, *args, **kwargs)
#     846         # N.B. doesn't cleanup query/fragment
#     847
# --> 848         new_query = self._get_str_query(*args, **kwargs)
#     849         return URL(
#     850             self._val._replace(path=self._val.path, query=new_query),
#
# ~\anaconda3\envs\x\lib\site-packages\yarl\__init__.py in _get_str_query(self, *args, **kwargs)
#     826             quoter = self._QUERY_PART_QUOTER
#     827             query = '&'.join(quoter(k) + '=' + quoter(v)
# --> 828                              for k, v in query)
#     829         else:
#     830             raise TypeError("Invalid query type: only str, mapping or "
#
# ~\anaconda3\envs\x\lib\site-packages\yarl\__init__.py in <genexpr>(.0)
#     826             quoter = self._QUERY_PART_QUOTER
#     827             query = '&'.join(quoter(k) + '=' + quoter(v)
# --> 828                              for k, v in query)
#     829         else:
#     830             raise TypeError("Invalid query type: only str, mapping or "
#
# ~\anaconda3\envs\x\lib\site-packages\yarl\_quoting.pyx in yarl._quoting._Quoter.__call__()
#
# TypeError: Argument should be str
